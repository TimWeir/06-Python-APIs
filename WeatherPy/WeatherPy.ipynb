# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from datetime import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

#Base URL for weather calls
url = "http://api.openweathermap.org/data/2.5/weather?"
#Imperial Units as stated in README.md
units = "imperial"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
city_count = len(cities)
city_count
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Loop weather request for the city list
query_url = f"{url}appid={weather_api_key}&units={units}&q="

city_name = []
long = []
lat = []
temp = []
hum = []
cloud = []
wind_speed = []
nation = []
date_cap = []

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        long.append(response['coord']['lon'])
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp_max'])
        hum.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        nation.append(response['sys']['country'])
        date_cap.append(response['dt'])
        print(f"Recording weather data {len(city_name)} of {city_count} ({city}).")
    except:
        print(f"Weather data not found {len(city_name)} of {city_count} ({city}).")
# Out:
# Recording weather data 1 of 604 (mar del plata).
# Recording weather data 2 of 604 (atuona).
# Recording weather data 3 of 604 (pouebo).
# Recording weather data 4 of 604 (rundu).
# Recording weather data 5 of 604 (khatanga).
# Recording weather data 6 of 604 (kyshtovka).
# Weather data not found 6 of 604 (attawapiskat).
# Recording weather data 7 of 604 (kahului).
# Recording weather data 8 of 604 (yellowknife).
# Recording weather data 9 of 604 (chokurdakh).
# Recording weather data 10 of 604 (ushuaia).
# Recording weather data 11 of 604 (punta arenas).
# Recording weather data 12 of 604 (pampa).
# Recording weather data 13 of 604 (cidreira).
# Recording weather data 14 of 604 (ancud).
# Recording weather data 15 of 604 (qaqortoq).
# Recording weather data 16 of 604 (balabac).
# Recording weather data 17 of 604 (coquimbo).
# Recording weather data 18 of 604 (kapit).
# Recording weather data 19 of 604 (virginia beach).
# Recording weather data 20 of 604 (qaanaaq).
# Recording weather data 21 of 604 (jamestown).
# Recording weather data 22 of 604 (ornskoldsvik).
# Recording weather data 23 of 604 (wonthaggi).
# Recording weather data 24 of 604 (talnakh).
# Recording weather data 25 of 604 (east london).
# Weather data not found 25 of 604 (rungata).
# Recording weather data 26 of 604 (san quintin).
# Recording weather data 27 of 604 (el tigre).
# Recording weather data 28 of 604 (ormara).
# Recording weather data 29 of 604 (georgetown).
# Recording weather data 30 of 604 (mataura).
# Recording weather data 31 of 604 (bambous virieux).
# Recording weather data 32 of 604 (aparecida do taboado).
# Recording weather data 33 of 604 (kyra).
# Recording weather data 34 of 604 (padang).
# Recording weather data 35 of 604 (new norfolk).
# Recording weather data 36 of 604 (carnarvon).
# Recording weather data 37 of 604 (katsuura).
# Recording weather data 38 of 604 (geraldton).
# Weather data not found 38 of 604 (vaitupu).
# Recording weather data 39 of 604 (rikitea).
# Recording weather data 40 of 604 (borogontsy).
# Recording weather data 41 of 604 (thompson).
# Recording weather data 42 of 604 (upernavik).
# Recording weather data 43 of 604 (dalvik).
# Weather data not found 43 of 604 (illoqqortoormiut).
# Recording weather data 44 of 604 (dikson).
# Recording weather data 45 of 604 (butaritari).
# Recording weather data 46 of 604 (qandala).
# Recording weather data 47 of 604 (lavrentiya).
# Recording weather data 48 of 604 (barrow).
# Recording weather data 49 of 604 (port hedland).
# Recording weather data 50 of 604 (kavieng).
# Recording weather data 51 of 604 (kapaa).
# Weather data not found 51 of 604 (sentyabrskiy).
# Weather data not found 51 of 604 (taolanaro).
# Recording weather data 52 of 604 (namie).
# Recording weather data 542 of 604 (lakes entrance).
# Recording weather data 543 of 604 (jeremie).
# Recording weather data 544 of 604 (brandon).
# Recording weather data 545 of 604 (kamina).
# Recording weather data 546 of 604 (micheweni).
# Recording weather data 547 of 604 (stolin).
# Recording weather data 548 of 604 (vyartsilya).
# Recording weather data 549 of 604 (kargasok).
# Recording weather data 550 of 604 (madera).
# Recording weather data 551 of 604 (kutum).
# Recording weather data 552 of 604 (alfenas).
# Recording weather data 553 of 604 (ascoli piceno).
# Recording weather data 554 of 604 (jaguarao).
# Recording weather data 555 of 604 (lethem).
# Recording weather data 556 of 604 (ulaanbaatar).
# Recording weather data 557 of 604 (amalapuram).
# Recording weather data 558 of 604 (shelburne).
# Recording weather data 559 of 604 (nouakchott).
# Recording weather data 560 of 604 (high level).
# Weather data not found 560 of 604 (tawnat).
# Weather data not found 560 of 604 (karauzyak).
# Recording weather data 561 of 604 (porecatu).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Build the dictionary of pulled data
weather_dict = {
                "City": city_name, "Latitude": lat, "Longitude": long, 
                "Max Temperature": temp, "Humidity": hum, "Cloudiness": cloud, 
                "Wind Speed": wind_speed, "Country": nation, "Date": date_cap
                }
#Build the DataFrame
weather_data = pd.DataFrame(weather_dict)

#Save DataFrame to CSV file
weather_data.to_csv(output_data_file, index=False, header=True)

#View DataFrame
weather_data.head()
# Out:
#             City  Latitude  Longitude  Max Temperature  Humidity  Cloudiness  \
# 0  Mar del Plata  -38.0023   -57.5575            64.99        67           0
# 1         Atuona   -9.8000  -139.0333            79.79        58           0
# 2         Pouébo  -20.4000   164.5667            82.18        68          26
# 3          Rundu  -17.9333    19.7667            65.43        63          63
# 4       Khatanga   71.9667   102.5000           -16.35        79         100
#
#    Wind Speed Country        Date
# 0        5.75      AR  1615600548
# 1        0.98      PF  1615600549
# 2       12.06      NC  1615600814
# 3        3.80      NA  1615600814
# 4       12.77      RU  1615600529

# %%
#Requested metrics
weather_data[['Latitude','Longitude','Max Temperature','Humidity','Cloudiness','Wind Speed','Date']].describe()
# Out:
#          Latitude   Longitude  Max Temperature    Humidity  Cloudiness  \
# count  561.000000  561.000000        561.00000  561.000000  561.000000
# mean    20.795238   16.275744         53.18590   72.254902   52.190731
# std     33.759364   91.247555         27.14024   20.355701   40.287152
# min    -54.800000 -179.166700        -20.61000    6.000000    0.000000
# 25%     -8.466700  -63.166700         35.62000   62.000000    5.000000
# 50%     25.487200   20.579100         61.05000   77.000000   60.000000
# 75%     50.599400   98.200000         75.20000   88.000000   94.000000
# max     78.218600  179.316700         95.00000  100.000000  100.000000
#
#        Wind Speed          Date
# count  561.000000  5.610000e+02
# mean     8.548378  1.615601e+09
# std      6.221660  1.573195e+02
# min      0.070000  1.615600e+09
# 25%      3.530000  1.615601e+09
# 50%      6.910000  1.615601e+09
# 75%     11.810000  1.615601e+09
# max     35.680000  1.615601e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
new_count = len(weather_data[weather_data['Humidity'] > 100])
print(f"There are {new_count} results with humidity over 100%.")

if new_count != 0:
    low_humidity_data = weather_data.drop(weather_data['Humidity'] > 100)
    low_humidity_data
# Out:
# There are 0 results with humidity over 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
low_humidity_index = []

#Grab the indeces if there are any rows with humidity over 100%
if new_count != 0:
    low_humidity_index = weather_data.index(weather_data['Humidity'] > 100).tolist()

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_weather_data = weather_data.drop(weather_data.index[low_humidity_index], inplace=False)
clean_weather_data.head()
# Out:
#             City  Latitude  Longitude  Max Temperature  Humidity  Cloudiness  \
# 0  Mar del Plata  -38.0023   -57.5575            64.99        67           0
# 1         Atuona   -9.8000  -139.0333            79.79        58           0
# 2         Pouébo  -20.4000   164.5667            82.18        68          26
# 3          Rundu  -17.9333    19.7667            65.43        63          63
# 4       Khatanga   71.9667   102.5000           -16.35        79         100
#
#    Wind Speed Country        Date
# 0        5.75      AR  1615600548
# 1        0.98      PF  1615600549
# 2       12.06      NC  1615600814
# 3        3.80      NA  1615600814
# 4       12.77      RU  1615600529

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Plot Latitute vs. Temperature
plt.scatter(clean_weather_data['Latitude'], clean_weather_data['Max Temperature'], marker="o", facecolors="red", edgecolors="black")

# Set a Title and labels
plt.title(f"Latitude vs. Max Temperature Plot ({datetime.now().date()})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.tight_layout()
plt.savefig("output_data/01_temp_plot.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Plot Latitute vs. Temperature
plt.scatter(clean_weather_data['Latitude'], clean_weather_data['Humidity'], marker="o", facecolors="green", edgecolors="black")

# Set a Title and labels
plt.title(f"Latitude vs. Humidity Plot ({datetime.now().date()})")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.tight_layout()
plt.savefig("output_data/02_humidity_plot.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Plot Latitute vs. Temperature
plt.scatter(clean_weather_data['Latitude'], clean_weather_data['Cloudiness'], marker="^", facecolors="blue", edgecolors="black")

# Set a Title and labels
plt.title(f"Latitude vs. Cloudiness Plot ({datetime.now().date()})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.tight_layout()
plt.savefig("output_data/03_cloudiness_plot.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_weather_data['Latitude'], clean_weather_data['Wind Speed'], marker="o", facecolors="yellow", edgecolors="black")

# Set a Title and labels
plt.title(f"Latitude vs. Wind Speed Plot ({datetime.now().date()})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.tight_layout()
plt.savefig("output_data/04_wind_plot.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
north_drop_index = []
south_drop_index = []

north_drop_index = clean_weather_data[(clean_weather_data['Latitude'] < 0)].index.tolist()
south_drop_index = clean_weather_data[(clean_weather_data['Latitude'] >= 0)].index.tolist()

north_df = clean_weather_data.drop(clean_weather_data.index[north_drop_index], inplace=False)
south_df = clean_weather_data.drop(clean_weather_data.index[south_drop_index], inplace=False)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = north_df['Latitude']
y_axis = north_df['Max Temperature']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis,y_axis)
reg_val = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,reg_val,"r-")
plt.annotate(line_eq,(0,100),fontsize=15,color="red")
plt.title(f"Northern Hemisphere \nMax Temp vs. Latitude Linear Regression \n({datetime.now().date()})")
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')
plt.xlim(0,90)
plt.tight_layout()
plt.savefig("output_data/05_north_temp_reg.png")
plt.show()
# Out:
# y = -1.24x + 93.4

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = south_df['Latitude']
y_axis = south_df['Max Temperature']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis,y_axis)
reg_val = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,reg_val,"r-")
plt.annotate(line_eq,(0,100),fontsize=15,color="red")
plt.title(f"Southern Hemisphere \nMax Temp vs. Latitude Linear Regression \n ({datetime.now().date()})")
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')
plt.xlim(-90,0)
plt.tight_layout()
plt.savefig("output_data/06_south_temp_reg.png")
plt.show()
# Out:
# y = 0.32x + 80.32

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = north_df['Latitude']
y_axis = north_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis,y_axis)
reg_val = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,reg_val,"r-")
plt.annotate(line_eq,(0,100),fontsize=15,color="red")
plt.title(f"Northern Hemisphere \nHumidity (%) vs. Latitude Linear Regression \n({datetime.now().date()})")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.xlim(0,90)
plt.tight_layout()
plt.savefig("output_data/07_north_humidity_reg.png")
plt.show()
# Out:
# y = 0.25x + 61.57

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = south_df['Latitude']
y_axis = south_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis,y_axis)
reg_val = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,reg_val,"r-")
plt.annotate(line_eq,(0,100),fontsize=15,color="red")
plt.title(f"Southern Hemisphere \nHumidity (%) vs. Latitude Linear Regression \n ({datetime.now().date()})")
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.xlim(-90,0)
plt.tight_layout()
plt.savefig("output_data/08_south_humidity_reg.png")
plt.show()
# Out:
# y = 0.37x + 82.32

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = north_df['Latitude']
y_axis = north_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis,y_axis)
reg_val = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,reg_val,"r-")
plt.annotate(line_eq,(0,100),fontsize=15,color="red")
plt.title(f"Northern Hemisphere \nCloudiness (%) vs. Latitude Linear Regression \n({datetime.now().date()})")
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
plt.xlim(0,90)
plt.tight_layout()
plt.savefig("output_data/09_north_cloudiness_reg.png")
plt.show()
# Out:
# y = 0.54x + 32.0

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = south_df['Latitude']
y_axis = south_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis,y_axis)
reg_val = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,reg_val,"r-")
plt.annotate(line_eq,(0,100),fontsize=15,color="red")
plt.title(f"Southern Hemisphere \nCloudiness (%) vs. Latitude Linear Regression \n ({datetime.now().date()})")
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
plt.xlim(-90,0)
plt.tight_layout()
plt.savefig("output_data/10_south_cloudiness_reg.png")
plt.show()
# Out:
# y = 0.69x + 64.06

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = north_df['Latitude']
y_axis = north_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis,y_axis)
reg_val = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,reg_val,"r-")
plt.annotate(line_eq,(0,100),fontsize=15,color="red")
plt.title(f"Northern Hemisphere \nMWind Speed (mph) vs. Latitude Linear Regression \n({datetime.now().date()})")
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.xlim(0,90)
plt.savefig("output_data/11_north_wind_reg.png")
plt.show()
# Out:
# y = 0.07x + 6.46

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = south_df['Latitude']
y_axis = south_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis,y_axis)
reg_val = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,reg_val,"r-")
plt.annotate(line_eq,(0,100),fontsize=15,color="red")
plt.title(f"Southern Hemisphere \nWind Speed (mph) vs. Latitude Linear Regression \n ({datetime.now().date()})")
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.xlim(-90,0)
plt.savefig("output_data/12_south_wind_reg.png")
plt.show()
# Out:
# y = -0.18x + 2.97
